# %% [raw]
# ---
# title: "17. Egocentric Vision : new task and trend survey"
# author: "이상민"
# date: "2/20/2026"
# ---

# %% [markdown]
# ## 1. Egocentric Vision
#
# ### 1) Difficulty
#
# * 심각한 self-occlusion
# * 시점 왜곡
# * 머리 움직임에 의한 모션 blur
# * Long-horizon 특성
#
# ### 2) 최근 성장의 원인
#
# * Meta Project Aria, Apple Vision Pro, Meta Quest 3와 같은 기기의 보급
# * Ego4D(3,670hour), EgoExo4D 등 대규모 데이터셋 공개
#
# ## 2. new task
#
# ### 1) Episodic Memory : 내가
