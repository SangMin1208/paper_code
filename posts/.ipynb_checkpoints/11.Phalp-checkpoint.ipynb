# %% [raw]
# ---
# title: "11. Phalp: Tracking People by Predicting 3D Appearance, Location and Pose(CVPR'22)"
# author: "이상민"
# date: "1/14/2026"
# ---

# %% [markdown]
# ## Phalp: Tracking People by Predicting 3D Appearance, Location and Pose(CVPR'22)
