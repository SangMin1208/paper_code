# %% [raw]
# ---
# title: "12. VGGT: Visual Geometry Grounded Transformer(CVPR'25)"
# author: "이상민"
# date: "1/15/2026"
# ---

# %% [markdown]
# ## VGGT: Visual Geometry Grounded Transformer(CVPR'25)
